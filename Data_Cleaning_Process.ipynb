# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('messy_customer_sales_data.csv')
df
# Out:
#       Customer_ID               Name  Gender         Age         City  \
# 0        CUST4371        Paul Wilson      m         52.0     KOLKATA
# 1        CUST5957       Jason Thomas       M  51.0 years          NaN
# 2        CUST3754  Brittney Martinez       F        62.0   hyderabad
# 3        CUST2934      Brenda Pierce  FEMALE        40.0   hyderabad
# 4        CUST5683    Matthew Carroll      f         41.0     CHENNAI
# ...           ...                ...     ...         ...          ...
# 10195   CUST10767       Robert Lewis  female  35.0 years       delhi
# 10196         NaN        Diane Evans       M        53.0   bangalore
# 10197    CUST6315    Joshua Martinez      m         25.0   hyderabad
# 10198    CUST4812       Sarah Miller  FEMALE        55.0          NaN
# 10199    CUST6588       David Potter  female        34.0   HYDERABAD
#
#       Signup_Date Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         9177 non-null   object
#  1   Name                10200 non-null  object
#  2   Gender              9174 non-null   object
#  3   Age                 9249 non-null   object
#  4   City                9184 non-null   object
#  5   Signup_Date         10200 non-null  object
#  6   Last_Purchase_Date  9188 non-null   object
#  7   Purchase_Amount     9179 non-null   float64
#  8   Feedback_Score      9177 non-null   float64
#  9   Email               10200 non-null  object
#  10  Phone_Number        10200 non-null  int64
#  11  Country             9468 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 956.4+ KB

# %%
df.describe().round()
# Out:
#        Purchase_Amount  Feedback_Score  Phone_Number
# count           9179.0          9177.0  1.020000e+04
# mean           29090.0             5.0  4.979974e+09
# std           208697.0             3.0  2.902593e+09
# min             -500.0             1.0  9.208990e+05
# 25%            12295.0             3.0  2.449157e+09
# 50%            24330.0             5.0  4.988639e+09
# 75%            37130.0             8.0  7.510448e+09
# max          9999999.0            10.0  9.994402e+09

# %%
df.isnull().sum()/len(df)*100
# Out:
# Customer_ID           10.029412
# Name                   0.000000
# Gender                10.058824
# Age                    9.323529
# City                   9.960784
# Signup_Date            0.000000
# Last_Purchase_Date     9.921569
# Purchase_Amount       10.009804
# Feedback_Score        10.029412
# Email                  0.000000
# Phone_Number           0.000000
# Country                7.176471
# dtype: float64

# %%
df.shape
# Out:
# (10200, 12)

# %%
# to find the missing data
df.dropna().shape
# Out:
# (4528, 12)

# %%
# to check number of duplicates entry 
df[df.duplicated()].shape
# Out:
# (15, 12)

# %%
# to check the duplicate entry
df[df.duplicated()]
# Out:
#       Customer_ID               Name  Gender   Age         City Signup_Date  \
# 2032     CUST2755     Casey Campbell    male   NaN   Hyderabad   2023-12-01
# 3191          NaN   Travis Schneider      f   51.0          NaN  2025-04-20
# 4312     CUST8305       Stanley Cain  FEMALE  51.0   Bangalore   2023-08-14
# 5611     CUST6288       Jonathon Kim    male  46.0     Chennai   2023-11-22
# 5680     CUST2695        Lisa Durham     NaN  46.0     Chennai   2021-04-18
# 5899     CUST8841        Amanda Hill     NaN  34.0     chennai   2022-09-11
# 6070    CUST10780        Emily Smith     NaN  23.0     Kolkata   2023-12-09
# 6240     CUST9745      David Morales     NaN  56.0          NaN  2023-02-18
# 6425     CUST4631       George Villa      m   26.0      Mumbai   2022-05-21
# 6498     CUST1711  Stephanie Elliott     NaN  44.0      MUMBAI   2023-05-17
# 7118     CUST9380        Paul Wilson    MALE  42.0   Bangalore   2025-07-31
# ...

# %%
# to check the repeated entry's
df['Customer_ID'].value_counts().head(10)
# Out:
# Customer_ID
# CUST3374     2
# CUST7749     2
# CUST10800    2
# CUST6588     2
# CUST9062     2
# CUST5472     2
# CUST1852     2
# CUST4160     2
# CUST5019     2
# CUST6288     2
# Name: count, dtype: int64

# %%
df[df['Customer_ID'] == 'CUST3374']
# Out:
#      Customer_ID             Name Gender   Age         City Signup_Date  \
# 2914    CUST3374  Timothy Wallace     m   58.0   Bangalore   2024-03-08
# 3047    CUST3374  Timothy Wallace     m   58.0   bangalore   2024-03-08
#
#      Last_Purchase_Date  Purchase_Amount  Feedback_Score                Email  \
# 2914         2025-08-21          45779.0             1.0  glenn95@example.org
# 3047         2025-08-21          45779.0             1.0  glenn95@example.org
#
#       Phone_Number Country
# 2914    9687701793   India
# 3047    9687701793   India

# %%
for col in df.columns:
    if df[col].nunique() < 20:
        print(df[col].value_counts())
        print('-'*50)
# Out:
# Gender
# f         1184
# M         1171
# m         1163
# F         1157
# MALE      1131
# female    1128
# male      1121
# FEMALE    1119
# Name: count, dtype: int64
# --------------------------------------------------
# City
# Kolkata       820
# Mumbai        812
# Chennai       784
# Bangalore     773
# Hyderabad     770
# Delhi         763
# CHENNAI       404
# KOLKATA       395
# MUMBAI        393
# hyderabad     384
# bangalore     383
# DELHI         378
# delhi         369
# BANGALORE     363
# HYDERABAD     360
# mumbai        352
# chennai       343
# kolkata       338
# Name: count, dtype: int64
# --------------------------------------------------
# Feedback_Score
# 2.0     952
# 4.0     947
# 7.0     938
# 6.0     927
# 3.0     913
# 8.0     912
# 1.0     907
# 9.0     903
# 10.0    901
# 5.0     877
# Name: count, dtype: int64
# --------------------------------------------------
# Country
# India    7132
# IND       793
# india     772
# InDia     771
# ...

# %% [markdown]
# Handling Missing Data

# %%
# Deleting the missing Data in Customer Id
df.dropna(subset = ['Customer_ID'], inplace = True)

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# Name                    0
# Gender                934
# Age                   859
# City                  918
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount       927
# Feedback_Score        905
# Email                   0
# Phone_Number            0
# Country               664
# dtype: int64

# %%
df
# Out:
#       Customer_ID               Name  Gender         Age         City  \
# 0        CUST4371        Paul Wilson      m         52.0     KOLKATA
# 1        CUST5957       Jason Thomas       M  51.0 years          NaN
# 2        CUST3754  Brittney Martinez       F        62.0   hyderabad
# 3        CUST2934      Brenda Pierce  FEMALE        40.0   hyderabad
# 4        CUST5683    Matthew Carroll      f         41.0     CHENNAI
# ...           ...                ...     ...         ...          ...
# 10194    CUST6146      Cody Thompson      f         40.0          NaN
# 10195   CUST10767       Robert Lewis  female  35.0 years       delhi
# 10197    CUST6315    Joshua Martinez      m         25.0   hyderabad
# 10198    CUST4812       Sarah Miller  FEMALE        55.0          NaN
# 10199    CUST6588       David Potter  female        34.0   HYDERABAD
#
#       Signup_Date Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
import re
def extract_age(age):
    age_num = re.findall('[0-9]+', str(age))
    if len(age_num)>0:
        return age_num[0]
    else:
        return age
df['Age'] = df['Age'].apply(lambda x: extract_age(x))

# %%
df
# Out:
#       Customer_ID               Name  Gender Age         City Signup_Date  \
# 0        CUST4371        Paul Wilson      m   52     KOLKATA   2025-06-26
# 1        CUST5957       Jason Thomas       M  51          NaN  2021-02-17
# 2        CUST3754  Brittney Martinez       F  62   hyderabad   2023-11-05
# 3        CUST2934      Brenda Pierce  FEMALE  40   hyderabad   2022-03-13
# 4        CUST5683    Matthew Carroll      f   41     CHENNAI   2024-04-05
# ...           ...                ...     ...  ..          ...         ...
# 10194    CUST6146      Cody Thompson      f   40          NaN  2024-08-21
# 10195   CUST10767       Robert Lewis  female  35       delhi   2020-12-08
# 10197    CUST6315    Joshua Martinez      m   25   hyderabad   2022-02-15
# 10198    CUST4812       Sarah Miller  FEMALE  55          NaN  2021-03-16
# 10199    CUST6588       David Potter  female  34   HYDERABAD   2020-10-12
#
#       Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df_age = df[df['Age'] != 'nan years'] ['Age']

# %%
age_median = int(df_age.dropna().astype('int64').median())

# %%
age_median
# Out:
# 43

# %%
df.replace('nan years', age_median, inplace = True)

# %%
df['Age'] = df['Age'].fillna(age_median)

# %%
df['Age'].unique()
# Out:
# array(['52', '51', '62', '40', '41', 43, '18', '43', '26', '32', '22',
#        '59', '65', '61', '31', '54', '55', '69', '24', '63', '19', '50',
#        '56', '36', '68', '38', '27', '57', '23', '25', '66', '28', '30',
#        '46', '48', '20', '37', '67', '35', '58', '29', '39', '49', '47',
#        '42', '44', '64', '53', '60', '45', '21', '34', '33', '250', '3',
#        '10'], dtype=object)

# %%
df['Purchase_Amount'] = df['Purchase_Amount'].fillna(
    df['Purchase_Amount'].median()
)

# %%
df['Feedback_Score'] = df['Feedback_Score'].fillna(
    df['Feedback_Score'].mode()[0]
)

# %%
# Out:
# Customer_ID             0
# Name                    0
# Gender                934
# Age                     0
# City                  918
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount         0
# Feedback_Score          0
# Email                   0
# Phone_Number            0
# Country               664
# dtype: int64

# %%
for col in ['Gender', 'City', 'Country']:
    mode_value = df[col].mode()[0]
    df[col] = df[col].fillna(mode_value)

# %%
# Out:
# Customer_ID             0
# Name                    0
# Gender                  0
# Age                     0
# City                    0
# Signup_Date             0
# Last_Purchase_Date    914
# Purchase_Amount         0
# Feedback_Score          0
# Email                   0
# Phone_Number            0
# Country                 0
# dtype: int64

# %%
df['Last_Purchase_Date'] = df['Last_Purchase_Date'].ffill()

# %%
df.isnull().sum()
# Out:
# Customer_ID           0
# Name                  0
# Gender                0
# Age                   0
# City                  0
# Signup_Date           0
# Last_Purchase_Date    0
# Purchase_Amount       0
# Feedback_Score        0
# Email                 0
# Phone_Number          0
# Country               0
# dtype: int64

# %% [markdown]
# ### Fixing Inconsistent Formatting

# %%
df['Gender'].unique()
# Out:
# array(['m ', 'M', 'F', 'FEMALE', 'f ', 'male', 'MALE', 'female'],
#       dtype=object)

# %%
df['Gender'] = df['Gender'].str.lower().str.strip()

# %%
df['Gender'] = df['Gender'].replace({
    'm': 'male',
    'f': 'female'
})

# %%
df['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['City'] = df['City'].str.strip().str.lower()

# %%
df['Country'] = df['Country'].str.lower()

# %%
df['Country'].replace({'ind': 'india'})
# Out:
# 0        india
# 1        india
# 2        india
# 3        india
# 4        india
#          ...
# 10194    india
# 10195    india
# 10197    india
# 10198    india
# 10199    india
# Name: Country, Length: 9177, dtype: object

# %%
df
# Out:
#       Customer_ID               Name  Gender Age       City Signup_Date  \
# 0        CUST4371        Paul Wilson    male  52    kolkata  2025-06-26
# 1        CUST5957       Jason Thomas    male  51    kolkata  2021-02-17
# 2        CUST3754  Brittney Martinez  female  62  hyderabad  2023-11-05
# 3        CUST2934      Brenda Pierce  female  40  hyderabad  2022-03-13
# 4        CUST5683    Matthew Carroll  female  41    chennai  2024-04-05
# ...           ...                ...     ...  ..        ...         ...
# 10194    CUST6146      Cody Thompson  female  40    kolkata  2024-08-21
# 10195   CUST10767       Robert Lewis  female  35      delhi  2020-12-08
# 10197    CUST6315    Joshua Martinez    male  25  hyderabad  2022-02-15
# 10198    CUST4812       Sarah Miller  female  55    kolkata  2021-03-16
# 10199    CUST6588       David Potter  female  34  hyderabad  2020-10-12
#
#       Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df[df.duplicated()].shape
# Out:
# (0, 12)

# %%
df.drop_duplicates(inplace = True)

# %%
df['Customer_ID'].value_counts()
# Out:
# Customer_ID
# CUST1923     2
# CUST10236    2
# CUST9062     2
# CUST8461     2
# CUST3060     2
#             ..
# CUST2393     1
# CUST10645    1
# CUST7130     1
# CUST10857    1
# CUST4812     1
# Name: count, Length: 9000, dtype: int64

# %%
df[df['Customer_ID'] == 'CUST1923']
# Out:
#      Customer_ID                Name Gender Age     City Signup_Date  \
# 1180    CUST1923  Amanda Sullivan MD   male  48  chennai  2024-07-09
# 4375    CUST1923  Amanda Sullivan MD   male  48  chennai  2024-07-09
#
#      Last_Purchase_Date  Purchase_Amount  Feedback_Score                Email  \
# 1180         2025-03-05          35269.0             6.0  james71@example.org
# 4375         2025-03-05          35269.0             6.0  james71@example.org
#
#       Phone_Number Country
# 1180    4005735737     ind
# 4375    4005735737   india

# %%
df.drop_duplicates(subset=['Customer_ID'], keep = 'first', inplace = True)

# %%
df.shape
# Out:
# (8986, 12)

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Name', 'Gender', 'Age', 'City', 'Signup_Date',
#        'Last_Purchase_Date', 'Purchase_Amount', 'Feedback_Score', 'Email',
#        'Phone_Number', 'Country'],
#       dtype='object')

# %%
df = df.copy()

# %%
df['Signup_Date'] = pd.to_datetime(df['Signup_Date'])

# %%
df['Last_Purchase_Date'] = pd.to_datetime(df['Last_Purchase_Date'])

# %%
df.dtypes
# Out:
# Customer_ID                   object
# Name                          object
# Gender                        object
# Age                            int64
# City                          object
# Signup_Date           datetime64[ns]
# Last_Purchase_Date    datetime64[ns]
# Purchase_Amount              float64
# Feedback_Score               float64
# Email                         object
# Phone_Number                   int64
# Country                       object
# dtype: object

# %% [markdown]
# ### Handling Outliners

# %%
print(df[['Age','Purchase_Amount','Feedback_Score']].dtypes)
# Out:
# Age                  int64
# Purchase_Amount    float64
# Feedback_Score     float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols = ['Age', 'Purchase_Amount', 'Feedback_Score']

plt.figure(figsize=(15,5))

for i, col in enumerate(cols, 1):
    plt.subplot(1, 3, i)
    sns.boxplot(y=df[col], color='skyblue', width=0.3)
    plt.title(f'Boxplot of {col}', fontsize = 12)
    plt.ylabel('')
    plt.grid(axis='y', linestyle='--', alpha = 0.6)

plt.tight_layout()
plt.show()

# %%
from scipy import stats

# %%
import numpy as np
z_scores = np.abs(stats.zscore(df[['Age','Purchase_Amount']]))

# %%
df_clean = df[~(z_scores>3).any(axis = 1)]

# %%
df_clean.shape
# Out:
# (8982, 12)

# %%
# Data Cleaning Process Is completted
